# %%
import pandas as pd

# %%
comprehensive_results= pd.read_csv('data/comprehensive_results.csv')

# %%
list(comprehensive_results
    )
# Out:
# ['ProductId',
#  'BranchId',
#  'CountryCode',
#  'Currency',
#  'EffectiveDate',
#  'ForecastStep',
#  'Demand',
#  'p10',
#  'p50',
#  'p90',
#  'AbsoluteError',
#  'PercentageError']

# %%
comprehensive_results[(comprehensive_results.ProductId==21)&(comprehensive_results.BranchId==13)&(comprehensive_results.Currency=='USD')]
# Out:
#      ProductId  BranchId CountryCode Currency EffectiveDate  ForecastStep  \
# 2           21        13          ZM      USD    2024-07-05             1
# 40          21        13          ZM      USD    2024-07-06             2
# 78          21        13          ZM      USD    2024-07-07             3
# 116         21        13          ZM      USD    2024-07-08             4
# 154         21        13          ZM      USD    2024-07-09             5
# 192         21        13          ZM      USD    2024-07-10             6
# 230         21        13          ZM      USD    2024-07-11             7
# 268         21        13          ZM      USD    2024-07-12             8
# 306         21        13          ZM      USD    2024-07-13             9
# 344         21        13          ZM      USD    2024-07-14            10
# 382         21        13          ZM      USD    2024-07-15            11
# 420         21        13          ZM      USD    2024-07-16            12
# ...
